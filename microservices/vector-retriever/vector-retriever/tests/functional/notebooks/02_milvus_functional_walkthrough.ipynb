# %% [markdown]
# # Milvus functional walkthrough
#
# This notebook mirrors the Milvus functional-test flow used by `tests/functional/test_milvus_filters.py` and the shared helpers in `tests/functional/conftest.py`, `tests/functional/data.py`, and `tests/functional/filter_assertions.py`.
#
# ## Prerequisites
# - Run the notebook from this repository with Docker available.
# - Expect the stack build to take time the first time it pulls images or prepares models.
# - The notebook seeds the deterministic fixture documents from `tests.functional.data.DOCUMENTS`.
# - For Milvus, the notebook intentionally restarts `vector-retriever` after seeding so the service re-initializes against the populated collection, matching the functional-test quirk in `conftest.py`.
#
# ## What this notebook demonstrates
# 1. Bring up the Milvus-backed `vector-retriever` stack with the same isolated ports used by the functional tests.
# 2. Wait for readiness and seed deterministic fixture data.
# 3. Validate `/health`, `/ready`, `/capabilities/filters`, and `/query`.
# 4. Exercise batch queries, `explain_filters`, `top_k` limiting, and every Milvus filter case from `FILTER_CASES` with one API call per code cell.
# 5. Tear the stack back down when exploration is complete.

# %%
from __future__ import annotations

import json
import os
import shutil
import subprocess
import sys
import time
from copy import deepcopy
from pathlib import Path
from typing import Any
from uuid import uuid4

import requests
from IPython.display import JSON, Markdown, display


def find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    for candidate in (start, *start.parents):
        if (candidate / 'pyproject.toml').exists() and (candidate / 'docker' / 'compose.yaml').exists():
            return candidate
    raise RuntimeError('Could not locate the repository root from the notebook working directory.')


REPO_ROOT = find_repo_root()
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from tests.functional.data import DOCUMENTS, FILTER_CASES

print(f'Repository root: {REPO_ROOT}')
print(f'Loaded {len(DOCUMENTS)} fixture documents and {len(FILTER_CASES)} filter cases.')
# Out:
# Repository root: /home/sdp/workbench/integration/edge-ai-libraries-helm/microservices/vector-retriever/vector-retriever
# Loaded 6 fixture documents and 20 filter cases.

# %% [markdown]
# ## Milvus-specific environment and port settings
#
# These values intentionally mirror `PORT_MAP["milvus"]` and the backend environment assembly in `tests/functional/conftest.py`.

# %%
BACKEND = 'milvus'
COMPOSE_PROJECT = 'docker'
OV_MODELS_SOURCE_VOLUME = 'docker_ov_models'
OV_MODELS_DEST_VOLUME = f'{COMPOSE_PROJECT}_ov-models'
DEFAULT_TEST_EMBEDDING_MODEL_NAME = 'CLIP/clip-vit-b-32'
PORT_SETTINGS = {
    'VECTOR_RETRIEVER_HOST_PORT': '6102',
    'EMBEDDING_SERVER_PORT': '9712',
    'MILVUS_HOST_PORT': '19531',
    'MILVUS_METRICS_HOST_PORT': '9092',
}


def build_backend_env() -> dict[str, str]:
    env = os.environ.copy()
    env.update(PORT_SETTINGS)
    index_name = f'vr_functional_{BACKEND}_{uuid4().hex[:8]}'
    env['RETRIEVER_BACKEND'] = BACKEND
    env['INDEX_NAME'] = index_name
    env['VS_INDEX_NAME'] = index_name
    env['EMBEDDING_MODEL_NAME'] = env.get('EMBEDDING_MODEL_NAME', '').strip() or DEFAULT_TEST_EMBEDDING_MODEL_NAME
    env['EMBEDDING_DEVICE'] = 'CPU'
    env['EMBEDDING_USE_OV'] = 'true'
    env["VECTOR_RETRIEVER_LOG_LEVEL"] = "debug"
    return env


ENV = build_backend_env()
BASE_URL = f"http://localhost:{ENV['VECTOR_RETRIEVER_HOST_PORT']}"
display(
    JSON(
        {
            'backend': BACKEND,
            'base_url': BASE_URL,
            'ports': PORT_SETTINGS,
            'index_name': ENV['INDEX_NAME'],
            'embedding_model_name': ENV['EMBEDDING_MODEL_NAME'],
            'embedding_device': ENV['EMBEDDING_DEVICE'],
            'embedding_use_ov': ENV['EMBEDDING_USE_OV'],
        },
        expanded=False,
    )
)

# %% [markdown]
# ## Local notebook helpers
#
# All helper functions live in this notebook so it is self-contained while still following the functional-test behavior closely.

# %%
def show_json(title: str, payload: Any, *, expanded: bool = False) -> None:
    display(Markdown(f'**{title}**'))
    display(JSON(payload, expanded=expanded))


def run_compose(env: dict[str, str], args: list[str]) -> subprocess.CompletedProcess:
    command = [
        'docker',
        'compose',
        '-f',
        'docker/compose.yaml',
        '-f',
        f'docker/compose.{BACKEND}.yaml',
        *args,
    ]
    print('$', ' '.join(command))
    completed = subprocess.run(
        command,
        cwd=REPO_ROOT,
        env=env,
        text=True,
        capture_output=True,
    )
    if completed.returncode != 0:
        raise RuntimeError(
            f'docker compose failed (exit {completed.returncode})\n'
            f'command: {command}\n'
            f'stdout:\n{completed.stdout}\n'
            f'stderr:\n{completed.stderr}'
        )
    if completed.stdout.strip():
        print(completed.stdout.strip())
    if completed.stderr.strip():
        print(completed.stderr.strip())
    return completed


def ensure_ov_models_volume() -> None:
    if subprocess.run(['docker', 'volume', 'inspect', OV_MODELS_DEST_VOLUME], capture_output=True).returncode == 0:
        print(f'Using existing volume: {OV_MODELS_DEST_VOLUME}')
        return

    if subprocess.run(['docker', 'volume', 'inspect', OV_MODELS_SOURCE_VOLUME], capture_output=True).returncode != 0:
        print(
            'Cached OV model volume not present; the embedding service may download or prepare models at runtime.'
        )
        return

    subprocess.run(['docker', 'volume', 'create', OV_MODELS_DEST_VOLUME], check=True, capture_output=True)
    subprocess.run(
        [
            'docker',
            'run',
            '--rm',
            '-v',
            f'{OV_MODELS_SOURCE_VOLUME}:/src',
            '-v',
            f'{OV_MODELS_DEST_VOLUME}:/dst',
            'alpine',
            'sh',
            '-c',
            'cp -r /src/. /dst/',
        ],
        check=True,
        capture_output=True,
    )
    print(f'Copied cached OV models into {OV_MODELS_DEST_VOLUME}')


def wait_for_ready(base_url: str, timeout_seconds: int = 600) -> dict[str, Any]:
    start = time.time()
    last_error = ''
    while time.time() - start < timeout_seconds:
        try:
            response = requests.get(f'{base_url}/ready', timeout=10)
            if response.status_code == 200:
                payload = response.json()
                if payload.get('status') == 'ready':
                    show_json('GET /ready', payload)
                    return payload
                last_error = f'unexpected /ready payload: {payload}'
            else:
                last_error = f'/ready returned {response.status_code}: {response.text}'
        except Exception as exc:  # noqa: BLE001
            last_error = str(exc)
        print('Waiting for readiness...', last_error or 'starting')
        time.sleep(3)
    raise AssertionError(f'vector-retriever did not become ready: {last_error}')


def seed_backend_data(env: dict[str, str]) -> subprocess.CompletedProcess:
    script = '\n'.join(
        [
            'import json',
            'from src.common.settings import settings',
            'from src.retriever.backend_factory import get_vectordb',
            f'expected_backend = {BACKEND!r}',
            "assert settings.RETRIEVER_BACKEND == expected_backend, (",
            "    f'backend mismatch: expected {expected_backend!r}, got {settings.RETRIEVER_BACKEND!r}'",
            ')',
            f'docs = json.loads({json.dumps(DOCUMENTS)!r})',
            'store = get_vectordb()',
            "texts = [item['page_content'] for item in docs]",
            "metadatas = [item['metadata'] for item in docs]",
            "ids = [item['metadata']['video_id'] for item in docs]",
            'try:',
            '    store.add_texts(texts=texts, metadatas=metadatas, ids=ids)',
            'except TypeError:',
            '    store.add_texts(texts=texts, metadatas=metadatas)',
            "print('seeded', len(docs))",
        ]
    )
    completed = run_compose(env, ['exec', '-T', 'vector-retriever', 'python', '-c', script])
    return completed


def api_get(path: str, *, timeout: int = 15, label: str | None = None) -> dict[str, Any]:
    response = requests.get(f'{BASE_URL}{path}', timeout=timeout)
    response.raise_for_status()
    payload = response.json()
    show_json(label or f'GET {path}', payload)
    return payload


def summarize_item(item: dict[str, Any]) -> dict[str, Any]:
    metadata = item.get('metadata', {})
    return {
        'video_id': metadata.get('video_id'),
        'camera_zone': metadata.get('camera_zone'),
        'frame_number': metadata.get('frame_number'),
        'bucket_name': metadata.get('bucket_name'),
        'tags': metadata.get('tags'),
        'score': item.get('score'),
    }


def extract_video_ids(result: dict[str, Any]) -> list[str]:
    return sorted(
        item.get('metadata', {}).get('video_id')
        for item in result.get('items', [])
        if item.get('metadata', {}).get('video_id')
    )


def summarize_result(result: dict[str, Any]) -> dict[str, Any]:
    return {
        'query_id': result.get('query_id'),
        'count': result.get('count'),
        'matched_ids': extract_video_ids(result),
        'applied_filters': result.get('applied_filters'),
        'items': [summarize_item(item) for item in result.get('items', [])],
    }


def api_query(payload: list[dict[str, Any]], *, timeout: int = 60, label: str = 'POST /query') -> dict[str, Any]:
    response = requests.post(f'{BASE_URL}/query', json=payload, timeout=timeout)
    response.raise_for_status()
    body = response.json()
    assert not body['errors'], body['errors']
    show_json(
        label,
        {
            'request_id': body.get('request_id'),
            'errors': body.get('errors'),
            'results': [summarize_result(result) for result in body.get('results', [])],
        },
        expanded=False,
    )
    return body


def verify_seed_visible(expected_count: int) -> dict[str, Any]:
    payload = [
        {
            'query_id': 'seed-verification',
            'query': 'fixture retrieval anchor',
            'top_k': 100,
        }
    ]
    body = api_query(payload, label='Seed verification query')
    count = body['results'][0]['count']
    assert count >= expected_count, f'expected at least {expected_count} seeded docs, got {count}'
    return body['results'][0]


def run_filter_case(case: dict[str, Any]) -> dict[str, Any]:
    payload = {
        'query_id': case['name'],
        'query': 'fixture retrieval anchor',
        'top_k': 100,
        'explain_filters': True,
    }
    payload.update(deepcopy(case['payload']))
    body = api_query([payload], label=f"Filter case: {case['name']}")
    result = body['results'][0]
    matched_ids = extract_video_ids(result)
    expected_ids = sorted(case['expected_ids'])
    assert matched_ids == expected_ids, (
        f"case={case['name']} expected={expected_ids} got={matched_ids}"
    )
    print(f"Matched IDs: {matched_ids}")
    return result


def teardown_stack(env: dict[str, str] = ENV, *, remove_volumes: bool = True, ignore_errors: bool = False) -> None:
    args = ['down']
    if remove_volumes:
        args.append('-v')
    args.append('--remove-orphans')
    try:
        run_compose(env, args)
    except Exception:
        if ignore_errors:
            print('No running stack to remove or cleanup failed harmlessly.')
        else:
            raise


FILTER_CASE_LOOKUP = {case['name']: case for case in FILTER_CASES}
show_json('Fixture video IDs', [doc['metadata']['video_id'] for doc in DOCUMENTS])
# Out:
# **Fixture video IDs**

# %% [markdown]
# ## Optional reset
#
# If a previous notebook run left the Milvus stack up, run this cleanup cell before starting fresh.

# %%
teardown_stack(ignore_errors=True)
# Out:
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml down -v --remove-orphans
# time="2026-04-08T07:16:31-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
#  Container docker-vector-retriever-1  Stopping
#  Container docker-vector-retriever-1  Stopped
#  Container docker-vector-retriever-1  Removing
#  Container docker-vector-retriever-1  Removed
#  Container docker-milvus-standalone-1  Stopping
#  Container multimodal-embedding-serving  Stopping
#  Container multimodal-embedding-serving  Stopped
#  Container multimodal-embedding-serving  Removing
#  Container multimodal-embedding-serving  Removed
#  Container docker-milvus-standalone-1  Stopped
#  Container docker-milvus-standalone-1  Removing
#  Container docker-milvus-standalone-1  Removed
#  Container docker-milvus-etcd-1  Stopping
#  Container docker-milvus-etcd-1  Stopped
#  Container docker-milvus-etcd-1  Removing
#  Container docker-milvus-etcd-1  Removed
#  Volume docker_data-prep  Removing
#  Volume docker_milvus-etcd  Removing
#  Volume docker_ov-models  Removing
#  Volume docker_milvus-db  Removing
#  Volume docker_data-prep  Removed
#  Network docker_vr_network  Removing
#  Volume docker_milvus-etcd  Removed
#  Network docker_vr_network  Removed
#  Volume docker_ov-models  Removed
#  Volume docker_milvus-db  Removed

# %% [markdown]
# ## Start the Milvus functional stack
#
# This uses the same compose files as the functional suite: `docker/compose.yaml` plus `docker/compose.milvus.yaml`.

# %%
ensure_ov_models_volume()
run_compose(ENV, ['up', '-d', '--build'])
run_compose(ENV, ['ps'])
# Out:
# Copied cached OV models into docker_ov-models
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml up -d --build
# #0 building with "default" instance using docker driver
#
# #1 [vector-retriever internal] load .dockerignore
# #1 transferring context: 2B done
# #1 DONE 0.0s
#
# #2 [vector-retriever internal] load build definition from Dockerfile
# #2 transferring dockerfile: 1.10kB done
# #2 DONE 0.0s
#
# #3 [vector-retriever internal] load metadata for docker.io/library/python:3.12.13-slim
# #3 DONE 0.3s
#
# #4 [vector-retriever 1/8] FROM docker.io/library/python:3.12.13-slim@sha256:5072b08ad74609c5329ab4085a96dfa873de565fb4751a4cfcd7dcc427661df0
# #4 resolve docker.io/library/python:3.12.13-slim@sha256:5072b08ad74609c5329ab4085a96dfa873de565fb4751a4cfcd7dcc427661df0 done
# #4 DONE 0.0s
#
# #5 [vector-retriever internal] load build context
# #5 transferring context: 5.78kB done
# #5 DONE 0.0s
#
# #6 [vector-retriever 3/8] WORKDIR /app
# #6 CACHED
#
# #7 [vector-retriever 4/8] COPY pyproject.toml README.md ./
# #7 CACHED
#
# #8 [vector-retriever 2/8] RUN groupadd --gid 1000 appuser &&     useradd --uid 1000 --gid appuser --shell /bin/bash --create-home appuser
# #8 CACHED
#
# #9 [vector-retriever 5/8] RUN pip install --upgrade pip &&     pip install poetry==2.3.3 &&     poetry config virtualenvs.create false &&         case "milvus" in             vdms|faiss|pgvector|milvus) ;;             *) echo "Unsupported RETRIEVER_BACKEND='milvus'" >&2; exit 1 ;;         esac &&         poetry install --only "main,backend-milvus" --no-root --sync
# #9 CACHED
#
# #10 [vector-retriever 6/8] COPY src ./src
# #10 CACHED
#
# #11 [vector-retriever 7/8] COPY scripts ./scripts
# #11 CACHED
#
# #12 [vector-retriever 8/8] RUN chmod +x /app/scripts/entrypoint.sh &&     chown -R appuser:appuser /app
# #12 CACHED
#
# #13 [vector-retriever] exporting to image
# #13 exporting layers done
# #13 writing image sha256:4a0cf95bde759ef76eb7c469463f09c5244b70f86a6a5f18261835f4e1fa78fe done
# #13 naming to docker.io/library/vector-retriever-milvus:latest done
# #13 DONE 0.0s
# time="2026-04-08T07:16:37-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
#  Network docker_vr_network  Creating
#  Network docker_vr_network  Created
#  Volume "docker_milvus-db"  Creating
#  Volume "docker_milvus-db"  Created
# time="2026-04-08T07:16:38-07:00" level=warning msg="volume \"docker_ov-models\" already exists but was not created by Docker Compose. Use `external: true` to use an existing volume"
#  Volume "docker_data-prep"  Creating
#  Volume "docker_data-prep"  Created
#  Volume "docker_milvus-etcd"  Creating
#  Volume "docker_milvus-etcd"  Created
#  Container multimodal-embedding-serving  Creating
#  Container docker-milvus-etcd-1  Creating
#  Container docker-milvus-etcd-1  Created
#  Container multimodal-embedding-serving  Created
#  Container docker-milvus-standalone-1  Creating
#  Container docker-milvus-standalone-1  Created
#  Container docker-vector-retriever-1  Creating
#  Container docker-vector-retriever-1  Created
#  Container multimodal-embedding-serving  Starting
#  Container docker-milvus-etcd-1  Starting
#  Container docker-milvus-etcd-1  Started
#  Container docker-milvus-etcd-1  Waiting
#  Container multimodal-embedding-serving  Started
#  Container docker-milvus-etcd-1  Healthy
#  Container docker-milvus-standalone-1  Starting
#  Container docker-milvus-standalone-1  Started
#  Container docker-vector-retriever-1  Starting
#  Container docker-vector-retriever-1  Started
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml ps
# NAME                           IMAGE                                       COMMAND                                                                                                             SERVICE                        CREATED          STATUS                                     PORTS
# docker-milvus-etcd-1           quay.io/coreos/etcd:v3.5.18                 "etcd -advertise-client-urls=http://127.0.0.1:2379 -listen-client-urls http://0.0.0.0:2379 --data-dir /etcd"        milvus-etcd                    32 seconds ago   Up 31 seconds (healthy)                    2379-2380/tcp
# docker-milvus-standalone-1     milvusdb/milvus:v2.6.14                     "/tini -- milvus run standalone"                                                                                    milvus-standalone              32 seconds ago   Up Less than a second (health: starting)   0.0.0.0:9092->9091/tcp, :::9092->9091/tcp, 0.0.0.0:19531->19530/tcp, :::19531->19530/tcp
# docker-vector-retriever-1      vector-retriever-milvus:latest              "/app/scripts/entrypoint.sh gunicorn -b 0.0.0.0:8000 -k uvicorn.workers.UvicornWorker src.main:app --timeout 300"   vector-retriever               32 seconds ago   Up Less than a second                      0.0.0.0:6102->8000/tcp, :::6102->8000/tcp
# multimodal-embedding-serving   intel/multimodal-embedding-serving:latest   "gunicorn -b 0.0.0.0:8000 -k uvicorn.workers.UvicornWorker src.app:app --timeout 300 --log-level debug"             multimodal-embedding-serving   32 seconds ago   Up 31 seconds (healthy)                    0.0.0.0:9712->8000/tcp, :::9712->8000/tcp
# time="2026-04-08T07:17:10-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
# CompletedProcess(args=['docker', 'compose', '-f', 'docker/compose.yaml', '-f', 'docker/compose.milvus.yaml', 'ps'], returncode=0, stdout='NAME                           IMAGE                                       COMMAND                                                                                                             SERVICE                        CREATED          STATUS                                     PORTS\ndocker-milvus-etcd-1           quay.io/coreos/etcd:v3.5.18                 "etcd -advertise-client-urls=http://127.0.0.1:2379 -listen-client-urls http://0.0.0.0:2379 --data-dir /etcd"        milvus-etcd                    32 seconds ago   Up 31 seconds (healthy)                    2379-2380/tcp\ndocker-milvus-standalone-1     milvusdb/milvus:v2.6.14                     "/tini -- milvus run standalone"                                                                                    milvus-standalone              32 seconds ago   Up Less than a second (health: starting)   0.0.0.0:9092->9091/tcp, :::9092->9091/tcp, 0.0.0.0:19531->19530/tcp, :::19531->19530/tcp\ndocker-vector-retriever-1      vector-retriever-milvus:latest              "/app/scripts/entrypoint.sh gunicorn -b 0.0.0.0:8000 -k uvicorn.workers.UvicornWorker src.main:app --timeout 300"   vector-retriever               32 seconds ago   Up Less than a second                      0.0.0.0:6102->8000/tcp, :::6102->8000/tcp\nmultimodal-embedding-serving   intel/multimodal-embedding-serving:latest   "gunicorn -b 0.0.0.0:8000 -k uvicorn.workers.UvicornWorker src.app:app --timeout 300 --log-level debug"             multimodal-embedding-serving   32 seconds ago   Up 31 seconds (healthy)                    0.0.0.0:9712->8000/tcp, :::9712->8000/tcp\n', stderr='time="2026-04-08T07:17:10-07:00" level=warning msg="The \\"REGISTRY\\" variable is not set. Defaulting to a blank string."\n')

# %% [markdown]
# ## Wait for service readiness
#
# Poll `/ready` until `vector-retriever` reports `status=ready`.

# %%
wait_for_ready(BASE_URL)
# Out:
# Waiting for readiness... ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# **GET /ready**
# {'status': 'ready', 'timestamp': '2026-04-08T14:17:16.279963Z'}

# %% [markdown]
# ## Seed deterministic fixture documents
#
# The seeded documents come directly from `tests.functional.data.DOCUMENTS`. After inserting them, restart `vector-retriever` so Milvus re-initializes against the populated collection, matching `tests/functional/conftest.py`.

# %%
seed_backend_data(ENV)
run_compose(ENV, ['restart', 'vector-retriever'])
wait_for_ready(BASE_URL)
# Out:
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml exec -T vector-retriever python -c import json
# from src.common.settings import settings
# from src.retriever.backend_factory import get_vectordb
# expected_backend = 'milvus'
# assert settings.RETRIEVER_BACKEND == expected_backend, (
#     f'backend mismatch: expected {expected_backend!r}, got {settings.RETRIEVER_BACKEND!r}'
# )
# docs = json.loads('[{"page_content": "red car at intersection", "metadata": {"video_id": "vid-001", "camera_zone": "north", "description": "red car at intersection", "prefix": "alpha-route", "frame_number": 10, "bucket_name": "cam-a", "tags": ["traffic", "vehicle", "red"], "created_at": "2026-03-10T10:00:00+00:00", "optional_note": "doc has note"}}, {"page_content": "blue bus near station", "metadata": {"video_id": "vid-002", "camera_zone": "south", "description": "blue bus near station", "prefix": "beta-route", "frame_number": 20, "bucket_name": "cam-b", "tags": ["traffic", "vehicle", "bus"], "created_at": "2026-03-15T12:00:00+00:00"}}, {"page_content": "person with bicycle crossing", "metadata": {"video_id": "vid-003", "camera_zone": "east", "description": "person with bicycle crossing", "prefix": "alpha-bike", "frame_number": 30, "bucket_name": "cam-c", "tags": ["pedestrian", "bicycle"], "created_at": "2026-03-20T08:30:00+00:00", "optional_note": "pedestrian event"}}, {"page_content": "delivery truck unloading", "metadata": {"video_id": "vid-004", "camera_zone": "west", "description": "delivery truck unloading", "prefix": "gamma-log", "frame_number": 40, "bucket_name": "cam-d", "tags": ["logistics", "vehicle"], "created_at": "2026-03-25T14:15:00+00:00"}}, {"page_content": "traffic light malfunction", "metadata": {"video_id": "vid-005", "camera_zone": "north-east", "description": "traffic light malfunction", "prefix": "alpha-signal", "frame_number": 50, "bucket_name": "cam-a", "tags": ["traffic", "signal"], "created_at": "2026-04-01T09:45:00+00:00", "optional_note": "signal issue"}}, {"page_content": "empty intersection at night", "metadata": {"video_id": "vid-006", "camera_zone": "south-west", "description": "empty intersection at night", "prefix": "delta-night", "frame_number": 60, "bucket_name": "cam-e", "tags": ["night", "traffic"], "created_at": "2026-04-05T20:10:00+00:00"}}]')
# store = get_vectordb()
# texts = [item['page_content'] for item in docs]
# metadatas = [item['metadata'] for item in docs]
# ids = [item['metadata']['video_id'] for item in docs]
# try:
#     store.add_texts(texts=texts, metadatas=metadatas, ids=ids)
# except TypeError:
#     store.add_texts(texts=texts, metadatas=metadatas)
# print('seeded', len(docs))
# seeded 6
# time="2026-04-08T07:17:16-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
# 2026-04-08 14:17:17,477 - DEBUG - Retrieving vector store for backend 'milvus'
# 2026-04-08 14:17:17,477 - DEBUG - Loading backend callable 'get_vectordb' from 'src.retriever.backends.milvus.backend'
# 2026-04-08 14:17:20,341 - INFO - Initializing Milvus backend for collection 'vr_functional_milvus_f2af982b' at 'http://milvus-standalone:19530'
# 2026-04-08 14:17:20,341 - DEBUG - Applied Milvus ORM alias compatibility patch
# 2026-04-08 14:17:20,444 - DEBUG - Retriever backend 'milvus' initialized successfully
# 2026-04-08 14:17:20,450 - DEBUG - Starting new HTTP connection (1): multimodal-embedding-serving:8000
# 2026-04-08 14:17:20,529 - DEBUG - http://multimodal-embedding-serving:8000 "POST /embeddings HTTP/1.1" 200 64935
# 2026-04-08 14:17:21,099 - DEBUG - Successfully created an index on vector field on collection: vr_functional_milvus_f2af982b
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml restart vector-retriever
# time="2026-04-08T07:17:22-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
#  Container docker-vector-retriever-1  Restarting
#  Container docker-vector-retriever-1  Started
# Waiting for readiness... ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# **GET /ready**
# {'status': 'ready', 'timestamp': '2026-04-08T14:17:29.581336Z'}

# %% [markdown]
# ## Verify the seed is visible
#
# Before exploring filters, make sure a broad query can see all seeded fixture records.

# %%
verify_seed_visible(expected_count=len(DOCUMENTS))
# Out:
# **Seed verification query**
# {'query_id': 'seed-verification',
#  'query': 'fixture retrieval anchor',
#  'count': 6,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': None,
#   'warnings': None,
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': None}}

# %% [markdown]
# ## Endpoint check: `/health`
#
# Confirm the service liveness endpoint returns `status="ok"`.

# %%
health_payload = api_get('/health')
assert health_payload['status'] == 'ok', health_payload
health_payload
# Out:
# **GET /health**
# {'status': 'ok', 'timestamp': '2026-04-08T14:17:29.805966Z'}

# %% [markdown]
# ## Endpoint check: `/ready`
#
# Confirm the ready endpoint still reports `status="ready"` after seeding and restart.

# %%
ready_payload = api_get('/ready')
assert ready_payload['status'] == 'ready', ready_payload
ready_payload
# Out:
# **GET /ready**
# {'status': 'ready', 'timestamp': '2026-04-08T14:17:29.831422Z'}

# %% [markdown]
# ## Endpoint check: `/capabilities/filters`
#
# Inspect the active backend and the advertised filter-capability surface.

# %%
capabilities_payload = api_get('/capabilities/filters')
assert capabilities_payload['active_backend'] == BACKEND, capabilities_payload
advertised_backends = {backend['backend'] for backend in capabilities_payload.get('backends', [])}
assert BACKEND in advertised_backends, advertised_backends
capabilities_payload
# Out:
# **GET /capabilities/filters**
# {'active_backend': 'milvus',
#  'backends': [{'backend': 'faiss',
#    'top_level_fields': ['query', 'top_k', 'where'],
#    'logical_blocks': ['all', 'any', 'not'],
#    'supported_operators': ['eq',
#     'in',
#     'contains',
#     'starts_with',
#     'gt',
#     'gte',
#     'lt',
#     'lte',
#     'between',
#     'contains_any',
#     'contains_all',
#     'exists',
#     'missing'],
#    'pushdown_operators': ['eq', 'in', 'gte', 'lte', 'between'],
#    'known_fields': {'tags': 'array<string>', 'created_at': 'datetime'},
#    'max_where_depth': 5,
#    'max_where_clauses': 50,
#    'max_where_list_size': 100},
#   {'backend': 'milvus',
#    'top_level_fields': ['query', 'top_k', 'where'],
#    'logical_blocks': ['all', 'any', 'not'],
#    'supported_operators': ['eq',
#     'in',
#     'contains',
#     'starts_with',
#     'gt',
#     'gte',
#     'lt',
#     'lte',
#     'between',
#     'contains_any',
#     'contains_all',
#     'exists',
#     'missing'],
#    'pushdown_operators': ['eq', 'in', 'gte', 'lte', 'between'],
#    'known_fields': {'tags': 'array<string>', 'created_at': 'datetime'},
#    'max_where_depth': 5,
#    'max_where_clauses': 50,
#    'max_where_list_size': 100},
#   {'backend': 'pgvector',
#    'top_level_fields': ['query', 'top_k', 'where'],
#    'logical_blocks': ['all', 'any', 'not'],
#    'supported_operators': ['eq',
#     'in',
#     'contains',
#     'starts_with',
#     'gt',
#     'gte',
#     'lt',
#     'lte',
#     'between',
#     'contains_any',
#     'contains_all',
#     'exists',
#     'missing'],
#    'pushdown_operators': ['eq', 'in', 'gte', 'lte', 'between'],
#    'known_fields': {'tags': 'array<string>', 'created_at': 'datetime'},
#    'max_where_depth': 5,
#    'max_where_clauses': 50,
#    'max_where_list_size': 100},
#   {'backend': 'vdms',
#    'top_level_fields': ['query', 'top_k', 'where'],
#    'logical_blocks': ['all', 'any', 'not'],
#    'supported_operators': ['eq',
#     'in',
#     'contains',
#     'starts_with',
#     'gt',
#     'gte',
#     'lt',
#     'lte',
#     'between',
#     'contains_any',
#     'contains_all',
#     'exists',
#     'missing'],
#    'pushdown_operators': ['gte', 'between'],
#    'known_fields': {'tags': 'array<string>', 'created_at': 'datetime'},
#    'max_where_depth': 5,
#    'max_where_clauses': 50,
#    'max_where_list_size': 100}]}

# %% [markdown]
# ## Endpoint check: `/query`
#
# Run a simple similarity query against the seeded collection before moving into the specialized filter checks.

# %%
smoke_query_body = api_query(
    [
        {
            'query_id': 'smoke-query',
            'query': 'fixture retrieval anchor',
            'top_k': 3,
        }
    ],
    label='Query smoke test',
)
assert smoke_query_body['results'][0]['count'] >= 3, smoke_query_body
smoke_query_body['results'][0]
# Out:
# **Query smoke test**
# {'query_id': 'smoke-query',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': None,
#   'warnings': None,
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': None}}

# %% [markdown]
# ## Batch query
#
# Mirror `assert_batch_query` by issuing two independent queries in a single `/query` call and checking that each response block returns the expected document.

# %%
batch_query_body = api_query(
    [
        {
            'query_id': 'batch-q1',
            'query': 'fixture retrieval anchor',
            'where': {'field': 'video_id', 'op': 'eq', 'value': 'vid-001'},
            'top_k': 10,
        },
        {
            'query_id': 'batch-q2',
            'query': 'fixture retrieval anchor',
            'where': {'field': 'video_id', 'op': 'eq', 'value': 'vid-002'},
            'top_k': 10,
        },
    ],
    label='Batch query check',
)
ids_q1 = extract_video_ids(batch_query_body['results'][0])
ids_q2 = extract_video_ids(batch_query_body['results'][1])
assert ids_q1 == ['vid-001'], ids_q1
assert ids_q2 == ['vid-002'], ids_q2
batch_query_body['results']
# Out:
# **Batch query check**
# [{'query_id': 'batch-q1',
#   'query': 'fixture retrieval anchor',
#   'count': 1,
#   'items': [{'score': 1.47770094871521,
#     'metadata': {'pk': 'vid-001',
#      'video_id': 'vid-001',
#      'camera_zone': 'north',
#      'description': 'red car at intersection',
#      'prefix': 'alpha-route',
#      'frame_number': 10,
#      'bucket_name': 'cam-a',
#      'tags': ['traffic', 'vehicle', 'red'],
#      'created_at': '2026-03-10T10:00:00+00:00',
#      'optional_note': 'doc has note'},
#     'page_content': 'red car at intersection'}],
#   'applied_filters': {'tags': None,
#    'time_filter': None,
#    'filters': None,
#    'normalized_where': {'field': 'video_id',
#     'op': 'eq',
#     'value': 'vid-001',
#     'all': None,
#     'any': None,
#     'not': None},
#    'warnings': None,
#    'compiled_backend_filter': None,
#    'dropped_or_rewritten_clauses': None}},
#  {'query_id': 'batch-q2',
#   'query': 'fixture retrieval anchor',
#   'count': 1,
#   'items': [{'score': 1.4708633422851562,
#     'metadata': {'pk': 'vid-002',
#      'video_id': 'vid-002',
#      'camera_zone': 'south',
#      'description': 'blue bus near station',
#      'prefix': 'beta-route',
#      'frame_number': 20,
#      'bucket_name': 'cam-b',
#      'tags': ['traffic', 'vehicle', 'bus'],
#      'created_at': '2026-03-15T12:00:00+00:00'},
#     'page_content': 'blue bus near station'}],
#   'applied_filters': {'tags': None,
#    'time_filter': None,
#    'filters': None,
#    'normalized_where': {'field': 'video_id',
#     'op': 'eq',
#     'value': 'vid-002',
#     'all': None,
#     'any': None,
#     'not': None},
#    'warnings': None,
#    'compiled_backend_filter': None,
#    'dropped_or_rewritten_clauses': None}}]

# %% [markdown]
# ## `explain_filters`
#
# Mirror `assert_explain_filters` and confirm the response includes a backend-compiled filter description when `explain_filters=True`.

# %%
explain_filters_body = api_query(
    [
        {
            'query_id': 'explain-test',
            'query': 'fixture retrieval anchor',
            'where': {'field': 'frame_number', 'op': 'gte', 'value': 50},
            'top_k': 10,
            'explain_filters': True,
        }
    ],
    label='Explain filters check',
)
applied_filters = explain_filters_body['results'][0]['applied_filters']
assert applied_filters.get('compiled_backend_filter') is not None, applied_filters
applied_filters
# Out:
# **Explain filters check**
# {'tags': None,
#  'time_filter': None,
#  'filters': None,
#  'normalized_where': {'field': 'frame_number',
#   'op': 'gte',
#   'value': 50,
#   'all': None,
#   'any': None,
#   'not': None},
#  'warnings': None,
#  'compiled_backend_filter': 'frame_number >= 50',
#  'dropped_or_rewritten_clauses': []}

# %% [markdown]
# ## `top_k` limiting
#
# Mirror `assert_top_k_limiting` and verify the service returns exactly two results when `top_k=2`.

# %%
top_k_body = api_query(
    [
        {
            'query_id': 'topk-limit',
            'query': 'fixture retrieval anchor',
            'top_k': 2,
        }
    ],
    label='Top-k limiting check',
)
top_k_result = top_k_body['results'][0]
assert top_k_result['count'] == 2, top_k_result
assert len(top_k_result['items']) == 2, top_k_result
top_k_result
# Out:
# **Top-k limiting check**
# {'query_id': 'topk-limit',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': None,
#   'warnings': None,
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': None}}

# %% [markdown]
# ## Filter-case walkthroughs
#
# The remaining cells mirror the parametrized `test_milvus_filter` cases. Each code cell below makes one `/query` request and validates the exact expected video IDs.

# %% [markdown]
# ### Filter case: `op_eq`
#
#             Exact-match filtering on a single scalar metadata field.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "video_id",
#     "op": "eq",
#     "value": "vid-001"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_eq'])
# Out:
# **Filter case: op_eq**
# Matched IDs: ['vid-001']
# {'query_id': 'op_eq',
#  'query': 'fixture retrieval anchor',
#  'count': 1,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'video_id',
#    'op': 'eq',
#    'value': 'vid-001',
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'video_id == "vid-001"',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_in`
#
#             Membership filtering against a list of allowed values.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "camera_zone",
#     "op": "in",
#     "value": [
#       "north",
#       "east"
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-003"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_in'])
# Out:
# **Filter case: op_in**
# Matched IDs: ['vid-001', 'vid-003']
# {'query_id': 'op_in',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'camera_zone',
#    'op': 'in',
#    'value': ['north', 'east'],
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'camera_zone in ["north", "east"]',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_contains`
#
#             Substring matching against free-text metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "description",
#     "op": "contains",
#     "value": "intersection"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-006"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_contains'])
# Out:
# **Filter case: op_contains**
# Matched IDs: ['vid-001', 'vid-006']
# {'query_id': 'op_contains',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'description',
#    'op': 'contains',
#    'value': 'intersection',
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate description:contains is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['description:contains']}}

# %% [markdown]
# ### Filter case: `op_starts_with`
#
#             Prefix matching for string metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "prefix",
#     "op": "starts_with",
#     "value": "alpha"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-003",
#   "vid-005"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_starts_with'])
# Out:
# **Filter case: op_starts_with**
# Matched IDs: ['vid-001', 'vid-003', 'vid-005']
# {'query_id': 'op_starts_with',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'prefix',
#    'op': 'starts_with',
#    'value': 'alpha',
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate prefix:starts_with is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['prefix:starts_with']}}

# %% [markdown]
# ### Filter case: `op_gt`
#
#             Strict greater-than filtering for numeric metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "frame_number",
#     "op": "gt",
#     "value": 40
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-005",
#   "vid-006"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_gt'])
# Out:
# **Filter case: op_gt**
# Matched IDs: ['vid-005', 'vid-006']
# {'query_id': 'op_gt',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'frame_number',
#    'op': 'gt',
#    'value': 40,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate frame_number:gt is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['frame_number:gt']}}

# %% [markdown]
# ### Filter case: `op_gte`
#
#             Greater-than-or-equal filtering for numeric metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "frame_number",
#     "op": "gte",
#     "value": 40
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-004",
#   "vid-005",
#   "vid-006"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_gte'])
# Out:
# **Filter case: op_gte**
# Matched IDs: ['vid-004', 'vid-005', 'vid-006']
# {'query_id': 'op_gte',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'frame_number',
#    'op': 'gte',
#    'value': 40,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'frame_number >= 40',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_lt`
#
#             Strict less-than filtering for numeric metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "frame_number",
#     "op": "lt",
#     "value": 30
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-002"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_lt'])
# Out:
# **Filter case: op_lt**
# Matched IDs: ['vid-001', 'vid-002']
# {'query_id': 'op_lt',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'frame_number',
#    'op': 'lt',
#    'value': 30,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate frame_number:lt is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['frame_number:lt']}}

# %% [markdown]
# ### Filter case: `op_lte`
#
#             Less-than-or-equal filtering for numeric metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "frame_number",
#     "op": "lte",
#     "value": 30
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-002",
#   "vid-003"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_lte'])
# Out:
# **Filter case: op_lte**
# Matched IDs: ['vid-001', 'vid-002', 'vid-003']
# {'query_id': 'op_lte',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'frame_number',
#    'op': 'lte',
#    'value': 30,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'frame_number <= 30',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_between`
#
#             Inclusive numeric range filtering.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "frame_number",
#     "op": "between",
#     "value": [
#       20,
#       40
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-002",
#   "vid-003",
#   "vid-004"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_between'])
# Out:
# **Filter case: op_between**
# Matched IDs: ['vid-002', 'vid-003', 'vid-004']
# {'query_id': 'op_between',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'frame_number',
#    'op': 'between',
#    'value': [20, 40],
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': '(frame_number >= 20 AND frame_number <= 40)',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_contains_any`
#
#             Array overlap filtering that matches any requested tag.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "tags",
#     "op": "contains_any",
#     "value": [
#       "bicycle",
#       "signal"
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-003",
#   "vid-005"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_contains_any'])
# Out:
# **Filter case: op_contains_any**
# Matched IDs: ['vid-003', 'vid-005']
# {'query_id': 'op_contains_any',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'tags',
#    'op': 'contains_any',
#    'value': ['bicycle', 'signal'],
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate tags:contains_any is evaluated in fallback path (list-typed field).'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['tags:contains_any']}}

# %% [markdown]
# ### Filter case: `op_contains_all`
#
#             Array containment filtering that requires every requested tag.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "tags",
#     "op": "contains_all",
#     "value": [
#       "traffic",
#       "vehicle"
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-002"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_contains_all'])
# Out:
# **Filter case: op_contains_all**
# Matched IDs: ['vid-001', 'vid-002']
# {'query_id': 'op_contains_all',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'tags',
#    'op': 'contains_all',
#    'value': ['traffic', 'vehicle'],
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate tags:contains_all is evaluated in fallback path (list-typed field).'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['tags:contains_all']}}

# %% [markdown]
# ### Filter case: `op_exists`
#
#             Field-presence filtering for optional metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "optional_note",
#     "op": "exists"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-003",
#   "vid-005"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_exists'])
# Out:
# **Filter case: op_exists**
# Matched IDs: ['vid-001', 'vid-003', 'vid-005']
# {'query_id': 'op_exists',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'optional_note',
#    'op': 'exists',
#    'value': None,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate optional_note:exists is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['optional_note:exists']}}

# %% [markdown]
# ### Filter case: `op_missing`
#
#             Field-absence filtering for optional metadata.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "optional_note",
#     "op": "missing"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-002",
#   "vid-004",
#   "vid-006"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_missing'])
# Out:
# **Filter case: op_missing**
# Matched IDs: ['vid-002', 'vid-004', 'vid-006']
# {'query_id': 'op_missing',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'optional_note',
#    'op': 'missing',
#    'value': None,
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': ['Predicate optional_note:missing is not backend-pushdown compatible and will be evaluated in fallback.'],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['optional_note:missing']}}

# %% [markdown]
# ### Filter case: `logical_compound`
#
#             Nested `all`/`any`/`not` logic composed into one request.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "all": [
#       {
#         "field": "frame_number",
#         "op": "gte",
#         "value": 20
#       },
#       {
#         "any": [
#           {
#             "field": "camera_zone",
#             "op": "eq",
#             "value": "east"
#           },
#           {
#             "field": "camera_zone",
#             "op": "eq",
#             "value": "west"
#           }
#         ]
#       },
#       {
#         "not": {
#           "field": "tags",
#           "op": "contains_any",
#           "value": [
#             "night"
#           ]
#         }
#       }
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-003",
#   "vid-004"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['logical_compound'])
# Out:
# **Filter case: logical_compound**
# Matched IDs: ['vid-003', 'vid-004']
# {'query_id': 'logical_compound',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': None,
#    'op': None,
#    'value': None,
#    'all': [{'field': 'frame_number',
#      'op': 'gte',
#      'value': 20,
#      'all': None,
#      'any': None,
#      'not': None},
#     {'field': None,
#      'op': None,
#      'value': None,
#      'all': None,
#      'any': [{'field': 'camera_zone',
#        'op': 'eq',
#        'value': 'east',
#        'all': None,
#        'any': None,
#        'not': None},
#       {'field': 'camera_zone',
#        'op': 'eq',
#        'value': 'west',
#        'all': None,
#        'any': None,
#        'not': None}],
#      'not': None},
#     {'field': None,
#      'op': None,
#      'value': None,
#      'all': None,
#      'any': None,
#      'not': {'field': 'tags',
#       'op': 'contains_any',
#       'value': ['night'],
#       'all': None,
#       'any': None,
#       'not': None}}],
#    'any': None,
#    'not': None},
#   'warnings': ["Logical clauses 'any'/'not' are evaluated in fallback path and not pushed down to backend.",
#    "Logical clauses 'any'/'not' are evaluated in fallback path and not pushed down to backend."],
#   'compiled_backend_filter': 'frame_number >= 20',
#   'dropped_or_rewritten_clauses': ['any(...)', 'not(...)']}}

# %% [markdown]
# ### Filter case: `legacy_tags_and_time_filter`
#
#             Backward-compatible legacy `tags` plus `time_filter` request shape.
#
#             **Request fragment**
#             ```json
#             {
#   "tags": [
#     "traffic"
#   ],
#   "time_filter": {
#     "end": "2026-04-02T00:00:00+00:00",
#     "start": "2026-03-12T00:00:00+00:00"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-002",
#   "vid-005"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['legacy_tags_and_time_filter'])
# Out:
# **Filter case: legacy_tags_and_time_filter**
# Matched IDs: ['vid-002', 'vid-005']
# {'query_id': 'legacy_tags_and_time_filter',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'}],
#  'applied_filters': {'tags': ['traffic'],
#   'time_filter': {'start': '2026-03-12T00:00:00Z',
#    'end': '2026-04-02T00:00:00Z'},
#   'filters': None,
#   'normalized_where': {'field': None,
#    'op': None,
#    'value': None,
#    'all': [{'field': 'tags',
#      'op': 'contains_any',
#      'value': ['traffic'],
#      'all': None,
#      'any': None,
#      'not': None},
#     {'field': 'created_at',
#      'op': 'between',
#      'value': ['2026-03-12T00:00:00Z', '2026-04-02T00:00:00Z'],
#      'all': None,
#      'any': None,
#      'not': None}],
#    'any': None,
#    'not': None},
#   'warnings': ["tags -> where(field='tags', op='contains_any', value=<tags>)",
#    "time_filter -> where(field='created_at', op='between', value=[start, end])",
#    'Predicate tags:contains_any is evaluated in fallback path (list-typed field).'],
#   'compiled_backend_filter': '(created_at >= "2026-03-12T00:00:00+00:00" AND created_at <= "2026-04-02T00:00:00+00:00")',
#   'dropped_or_rewritten_clauses': ["tags -> where(field='tags', op='contains_any', value=<tags>)",
#    "time_filter -> where(field='created_at', op='between', value=[start, end])",
#    'tags:contains_any']}}

# %% [markdown]
# ### Filter case: `legacy_filters_map`
#
#             Backward-compatible legacy `filters` map request shape.
#
#             **Request fragment**
#             ```json
#             {
#   "filters": {
#     "bucket_name": {
#       "op": "in",
#       "value": [
#         "cam-a",
#         "cam-b"
#       ]
#     },
#     "frame_number": {
#       "op": "between",
#       "value": [
#         10,
#         20
#       ]
#     }
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-001",
#   "vid-002"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['legacy_filters_map'])
# Out:
# **Filter case: legacy_filters_map**
# Matched IDs: ['vid-001', 'vid-002']
# {'query_id': 'legacy_filters_map',
#  'query': 'fixture retrieval anchor',
#  'count': 2,
#  'items': [{'score': 1.47770094871521,
#    'metadata': {'pk': 'vid-001',
#     'video_id': 'vid-001',
#     'camera_zone': 'north',
#     'description': 'red car at intersection',
#     'prefix': 'alpha-route',
#     'frame_number': 10,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'vehicle', 'red'],
#     'created_at': '2026-03-10T10:00:00+00:00',
#     'optional_note': 'doc has note'},
#    'page_content': 'red car at intersection'},
#   {'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': {'bucket_name': {'op': 'in', 'value': ['cam-a', 'cam-b']},
#    'frame_number': {'op': 'between', 'value': [10, 20]}},
#   'normalized_where': {'field': None,
#    'op': None,
#    'value': None,
#    'all': [{'field': 'bucket_name',
#      'op': 'in',
#      'value': ['cam-a', 'cam-b'],
#      'all': None,
#      'any': None,
#      'not': None},
#     {'field': 'frame_number',
#      'op': 'between',
#      'value': [10, 20],
#      'all': None,
#      'any': None,
#      'not': None}],
#    'any': None,
#    'not': None},
#   'warnings': ['filters -> where(all=[legacy predicates])'],
#   'compiled_backend_filter': 'bucket_name in ["cam-a", "cam-b"] AND (frame_number >= 10 AND frame_number <= 20)',
#   'dropped_or_rewritten_clauses': ['filters -> where(all=[legacy predicates])']}}

# %% [markdown]
# ### Filter case: `logical_not_toplevel`
#
#             Top-level logical negation without extra nesting.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "not": {
#       "field": "camera_zone",
#       "op": "eq",
#       "value": "north"
#     }
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-002",
#   "vid-003",
#   "vid-004",
#   "vid-005",
#   "vid-006"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['logical_not_toplevel'])
# Out:
# **Filter case: logical_not_toplevel**
# Matched IDs: ['vid-002', 'vid-003', 'vid-004', 'vid-005', 'vid-006']
# {'query_id': 'logical_not_toplevel',
#  'query': 'fixture retrieval anchor',
#  'count': 5,
#  'items': [{'score': 1.4708633422851562,
#    'metadata': {'pk': 'vid-002',
#     'video_id': 'vid-002',
#     'camera_zone': 'south',
#     'description': 'blue bus near station',
#     'prefix': 'beta-route',
#     'frame_number': 20,
#     'bucket_name': 'cam-b',
#     'tags': ['traffic', 'vehicle', 'bus'],
#     'created_at': '2026-03-15T12:00:00+00:00'},
#    'page_content': 'blue bus near station'},
#   {'score': 1.2737725973129272,
#    'metadata': {'pk': 'vid-006',
#     'video_id': 'vid-006',
#     'camera_zone': 'south-west',
#     'description': 'empty intersection at night',
#     'prefix': 'delta-night',
#     'frame_number': 60,
#     'bucket_name': 'cam-e',
#     'tags': ['night', 'traffic'],
#     'created_at': '2026-04-05T20:10:00+00:00'},
#    'page_content': 'empty intersection at night'},
#   {'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': None,
#    'op': None,
#    'value': None,
#    'all': None,
#    'any': None,
#    'not': {'field': 'camera_zone',
#     'op': 'eq',
#     'value': 'north',
#     'all': None,
#     'any': None,
#     'not': None}},
#   'warnings': ["Logical clauses 'any'/'not' are evaluated in fallback path and not pushed down to backend."],
#   'compiled_backend_filter': None,
#   'dropped_or_rewritten_clauses': ['not(...)']}}

# %% [markdown]
# ### Filter case: `no_match`
#
#             A negative control that should return an empty result set.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "video_id",
#     "op": "eq",
#     "value": "vid-999"
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             []
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['no_match'])
# Out:
# **Filter case: no_match**
# Matched IDs: []
# {'query_id': 'no_match',
#  'query': 'fixture retrieval anchor',
#  'count': 0,
#  'items': [],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'video_id',
#    'op': 'eq',
#    'value': 'vid-999',
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'video_id == "vid-999"',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `op_time_between_where`
#
#             Datetime range filtering expressed through the modern `where` grammar.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "field": "created_at",
#     "op": "between",
#     "value": [
#       "2026-03-20T00:00:00+00:00",
#       "2026-04-01T23:59:59+00:00"
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-003",
#   "vid-004",
#   "vid-005"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['op_time_between_where'])
# Out:
# **Filter case: op_time_between_where**
# Matched IDs: ['vid-003', 'vid-004', 'vid-005']
# {'query_id': 'op_time_between_where',
#  'query': 'fixture retrieval anchor',
#  'count': 3,
#  'items': [{'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'},
#   {'score': 0.9245082139968872,
#    'metadata': {'pk': 'vid-005',
#     'video_id': 'vid-005',
#     'camera_zone': 'north-east',
#     'description': 'traffic light malfunction',
#     'prefix': 'alpha-signal',
#     'frame_number': 50,
#     'bucket_name': 'cam-a',
#     'tags': ['traffic', 'signal'],
#     'created_at': '2026-04-01T09:45:00+00:00',
#     'optional_note': 'signal issue'},
#    'page_content': 'traffic light malfunction'},
#   {'score': 0.9070421457290649,
#    'metadata': {'pk': 'vid-004',
#     'video_id': 'vid-004',
#     'camera_zone': 'west',
#     'description': 'delivery truck unloading',
#     'prefix': 'gamma-log',
#     'frame_number': 40,
#     'bucket_name': 'cam-d',
#     'tags': ['logistics', 'vehicle'],
#     'created_at': '2026-03-25T14:15:00+00:00'},
#    'page_content': 'delivery truck unloading'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': 'created_at',
#    'op': 'between',
#    'value': ['2026-03-20T00:00:00+00:00', '2026-04-01T23:59:59+00:00'],
#    'all': None,
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': '(created_at >= "2026-03-20T00:00:00+00:00" AND created_at <= "2026-04-01T23:59:59+00:00")',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ### Filter case: `nested_all`
#
#             Nested `all` groups to prove recursive boolean composition works.
#
#             **Request fragment**
#             ```json
#             {
#   "where": {
#     "all": [
#       {
#         "all": [
#           {
#             "field": "frame_number",
#             "op": "gte",
#             "value": 10
#           },
#           {
#             "field": "frame_number",
#             "op": "lte",
#             "value": 30
#           }
#         ]
#       },
#       {
#         "field": "bucket_name",
#         "op": "eq",
#         "value": "cam-c"
#       }
#     ]
#   }
# }
#             ```
#
#             **Expected video IDs**
#             ```json
#             [
#   "vid-003"
# ]
#             ```

# %%
run_filter_case(FILTER_CASE_LOOKUP['nested_all'])
# Out:
# **Filter case: nested_all**
# Matched IDs: ['vid-003']
# {'query_id': 'nested_all',
#  'query': 'fixture retrieval anchor',
#  'count': 1,
#  'items': [{'score': 1.1559451818466187,
#    'metadata': {'pk': 'vid-003',
#     'video_id': 'vid-003',
#     'camera_zone': 'east',
#     'description': 'person with bicycle crossing',
#     'prefix': 'alpha-bike',
#     'frame_number': 30,
#     'bucket_name': 'cam-c',
#     'tags': ['pedestrian', 'bicycle'],
#     'created_at': '2026-03-20T08:30:00+00:00',
#     'optional_note': 'pedestrian event'},
#    'page_content': 'person with bicycle crossing'}],
#  'applied_filters': {'tags': None,
#   'time_filter': None,
#   'filters': None,
#   'normalized_where': {'field': None,
#    'op': None,
#    'value': None,
#    'all': [{'field': None,
#      'op': None,
#      'value': None,
#      'all': [{'field': 'frame_number',
#        'op': 'gte',
#        'value': 10,
#        'all': None,
#        'any': None,
#        'not': None},
#       {'field': 'frame_number',
#        'op': 'lte',
#        'value': 30,
#        'all': None,
#        'any': None,
#        'not': None}],
#      'any': None,
#      'not': None},
#     {'field': 'bucket_name',
#      'op': 'eq',
#      'value': 'cam-c',
#      'all': None,
#      'any': None,
#      'not': None}],
#    'any': None,
#    'not': None},
#   'warnings': None,
#   'compiled_backend_filter': 'frame_number <= 30 AND bucket_name == "cam-c"',
#   'dropped_or_rewritten_clauses': []}}

# %% [markdown]
# ## Final teardown
#
# When you are done exploring, tear down the compose stack and remove its volumes so the notebook leaves the environment clean.

# %%
teardown_stack()
# Out:
# $ docker compose -f docker/compose.yaml -f docker/compose.milvus.yaml down -v --remove-orphans
# time="2026-04-08T07:17:31-07:00" level=warning msg="The \"REGISTRY\" variable is not set. Defaulting to a blank string."
#  Container docker-vector-retriever-1  Stopping
#  Container docker-vector-retriever-1  Stopped
#  Container docker-vector-retriever-1  Removing
#  Container docker-vector-retriever-1  Removed
#  Container docker-milvus-standalone-1  Stopping
#  Container multimodal-embedding-serving  Stopping
#  Container multimodal-embedding-serving  Stopped
#  Container multimodal-embedding-serving  Removing
#  Container multimodal-embedding-serving  Removed
#  Container docker-milvus-standalone-1  Stopped
#  Container docker-milvus-standalone-1  Removing
#  Container docker-milvus-standalone-1  Removed
#  Container docker-milvus-etcd-1  Stopping
#  Container docker-milvus-etcd-1  Stopped
#  Container docker-milvus-etcd-1  Removing
#  Container docker-milvus-etcd-1  Removed
#  Volume docker_milvus-db  Removing
#  Volume docker_ov-models  Removing
#  Volume docker_data-prep  Removing
#  Volume docker_milvus-etcd  Removing
#  Network docker_vr_network  Removing
#  Volume docker_milvus-db  Removed
#  Network docker_vr_network  Removed
#  Volume docker_ov-models  Removed
#  Volume docker_milvus-etcd  Removed
#  Volume docker_data-prep  Removed
