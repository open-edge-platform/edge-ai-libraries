# %% [markdown]
# # GETI Server Connection and API Integration
#
# This notebook demonstrates how to connect to a GETI server and leverage the GETI SDK API for various tasks. The workflow includes:
#
# - **Authentication**: Establishing a secure connection to the GETI server
# - **API Exploration**: Understanding available endpoints and methods
# - **Data Operations**: Performing CRUD operations on projects, models, and datasets
# - **Inference**: Running predictions using trained models
# - **Workflow Automation**: Automating common tasks through the SDK
#
# The GETI SDK provides a Python interface for programmatic access to GETI's computer vision capabilities, enabling seamless integration with your ML pipelines.

# %% [markdown]
# ### Install GETI SDK
# pip install geti-sdk
# - # Specific version
# pip install geti-sdk==2.12.0
# - # Set up environment variables for GETI server connection
# GETI_HOST, GETI_TOKEN, GETI_SERVER_API_VERSION, GETI_ORGANIZATION_ID, and GETI_WORKSPACE_ID

# %%
# !pip install geti-sdk==2.12.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#export env variables
export GETI_HOST=""
export GETI_TOKEN="" 
export GETI_SERVER_API_VERSION=""
export GETI_ORGANIZATION_ID=""
export GETI_WORKSPACE_ID=""
